# %%
import torch
import torchvision
import numpy as np
import torch.multiprocessing as mp
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
import torch.nn as nn
import matplotlib.pyplot as plt
import torch.nn.functional as F
import seaborn as sns
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import os
import copy
import warnings
#importing custom py file with functions and the CLPSO algorithm

# %%
try:
    import CLPSO_GRAD_script
except Exception as e:
    print("Failed to import script:", e)

# %%
#Setting CUDA and multiprocessing
mp.set_start_method('spawn', force=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define and load model
model = CLPSO_GRAD_script.my_CNN()
PATH = '/school/intelligence_coursework/new_CNN/trained_network/new_CNN_notebook.pth'
model.load_state_dict(torch.load(PATH, map_location=device))

#Using GPU
model = model.to(device)
print("Model device:", next(model.parameters()).device)
# Out:
# Model device: cuda:0

# %%
# Load and preprocess CIFAR-10 data
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

#augmented images for trainset
augmented_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.RandomCrop(32, padding=4),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=augmented_transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=512, shuffle=True, num_workers=0)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=512, shuffle=False, num_workers=0)

classes = trainset.classes
criterion = nn.CrossEntropyLoss()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
trained_model, epoch_losses, epoch_precisions = CLPSO_GRAD_script.run_clpso(PATH, testloader, criterion, fine_tune_epochs=15, num_particles=10)
# Out:
# Epoch 1/15
# Particle 1 evaluated. Fitness: 4.0136
# Particle 2 evaluated. Fitness: 4.5931
# Particle 3 evaluated. Fitness: 4.2076
# Particle 4 evaluated. Fitness: 4.1043
# Particle 5 evaluated. Fitness: 4.5261
# Particle 6 evaluated. Fitness: 4.8751
# Particle 7 evaluated. Fitness: 4.9914
# Particle 8 evaluated. Fitness: 4.1804
# Particle 9 evaluated. Fitness: 4.4563
# Particle 10 evaluated. Fitness: 4.2417
# New global best fitness: 4.0136
# Epoch 1/15 - Validation Loss: 1.9433, Precision: 0.4080
# Epoch 1/15 - Best Global Fitness: 4.0136
# Epoch 2/15
# Particle 1 evaluated. Fitness: 2.5306
# Particle 2 evaluated. Fitness: 2.8262
# Particle 3 evaluated. Fitness: 2.5808
# Particle 4 evaluated. Fitness: 2.4203
# Particle 5 evaluated. Fitness: 2.6752
# Particle 6 evaluated. Fitness: 2.9260
# Particle 7 evaluated. Fitness: 2.8883
# Particle 8 evaluated. Fitness: 2.4799
# Particle 9 evaluated. Fitness: 2.5211
# Particle 10 evaluated. Fitness: 2.4946
# New global best fitness: 2.5306
# New global best fitness: 2.4203
# Epoch 2/15 - Validation Loss: 0.8867, Precision: 0.7022
# Epoch 2/15 - Best Global Fitness: 2.4203
# Epoch 3/15
# Particle 1 evaluated. Fitness: 1.7182
# Particle 2 evaluated. Fitness: 1.9297
# Particle 3 evaluated. Fitness: 1.6995
# Particle 4 evaluated. Fitness: 1.7455
# Particle 5 evaluated. Fitness: 2.0047
# Particle 6 evaluated. Fitness: 1.9383
# Particle 7 evaluated. Fitness: 1.8453
# Particle 8 evaluated. Fitness: 1.6490
# Particle 9 evaluated. Fitness: 1.6875
# Particle 10 evaluated. Fitness: 1.7159
# New global best fitness: 1.7182
# New global best fitness: 1.6995
# New global best fitness: 1.6490
# Epoch 3/15 - Validation Loss: 0.6530, Precision: 0.7755
# Epoch 3/15 - Best Global Fitness: 1.6490
# Epoch 4/15
# Particle 1 evaluated. Fitness: 1.2742
# Particle 2 evaluated. Fitness: 1.5521
# Particle 3 evaluated. Fitness: 1.2787
# Particle 4 evaluated. Fitness: 1.3086
# Particle 5 evaluated. Fitness: 1.5138
# Particle 6 evaluated. Fitness: 1.4351
# Particle 7 evaluated. Fitness: 1.3599
# Particle 8 evaluated. Fitness: 1.2791
# Particle 9 evaluated. Fitness: 1.3155
# Particle 10 evaluated. Fitness: 1.3317
# New global best fitness: 1.2742
# Epoch 4/15 - Validation Loss: 0.5852, Precision: 0.7997
# Epoch 4/15 - Best Global Fitness: 1.2742
# Epoch 5/15
# Particle 1 evaluated. Fitness: 1.0777
# Particle 2 evaluated. Fitness: 1.1018
# Particle 3 evaluated. Fitness: 1.0474
# Particle 4 evaluated. Fitness: 1.1009
# Particle 5 evaluated. Fitness: 1.1277
# Particle 6 evaluated. Fitness: 1.1078
# Particle 7 evaluated. Fitness: 1.0640
# Particle 8 evaluated. Fitness: 1.0824
# Particle 9 evaluated. Fitness: 1.0597
# Particle 10 evaluated. Fitness: 1.0470
# New global best fitness: 1.0777
# New global best fitness: 1.0474
# New global best fitness: 1.0470
# Epoch 5/15 - Validation Loss: 0.5546, Precision: 0.8111
# Epoch 5/15 - Best Global Fitness: 1.0470
# Epoch 6/15
# Particle 1 evaluated. Fitness: 0.9381
# Particle 2 evaluated. Fitness: 0.9396
# Particle 3 evaluated. Fitness: 0.9388
# Particle 4 evaluated. Fitness: 0.9267
# Particle 5 evaluated. Fitness: 0.9657
# Particle 6 evaluated. Fitness: 0.9477
# Particle 7 evaluated. Fitness: 0.9239
# Particle 8 evaluated. Fitness: 0.9393
# Particle 9 evaluated. Fitness: 0.9020
# Particle 10 evaluated. Fitness: 0.9577
# New global best fitness: 0.9381
# New global best fitness: 0.9267
# New global best fitness: 0.9239
# New global best fitness: 0.9020
# Epoch 6/15 - Validation Loss: 0.5252, Precision: 0.8271
# Epoch 6/15 - Best Global Fitness: 0.9020
# Epoch 7/15
# Particle 1 evaluated. Fitness: 0.8675
# Particle 2 evaluated. Fitness: 0.8822
# Particle 3 evaluated. Fitness: 0.8677
# Particle 4 evaluated. Fitness: 0.8858
# Particle 5 evaluated. Fitness: 0.8883
# Particle 6 evaluated. Fitness: 0.8522
# Particle 7 evaluated. Fitness: 0.8670
# Particle 8 evaluated. Fitness: 0.8681
# Particle 9 evaluated. Fitness: 0.8855
# Particle 10 evaluated. Fitness: 0.8633
# New global best fitness: 0.8675
# New global best fitness: 0.8522
# Epoch 7/15 - Validation Loss: 0.5055, Precision: 0.8307
# Epoch 7/15 - Best Global Fitness: 0.8522
# Epoch 8/15
# Particle 1 evaluated. Fitness: 0.8457
# Particle 2 evaluated. Fitness: 0.8234
# Particle 3 evaluated. Fitness: 0.8377
# Particle 4 evaluated. Fitness: 0.8422
# Particle 5 evaluated. Fitness: 0.8376
# Particle 6 evaluated. Fitness: 0.8516
# Particle 7 evaluated. Fitness: 0.8421
# Particle 8 evaluated. Fitness: 0.8288
# Particle 9 evaluated. Fitness: 0.8509
# Particle 10 evaluated. Fitness: 0.8395
# New global best fitness: 0.8457
# New global best fitness: 0.8234
# Epoch 8/15 - Validation Loss: 0.4884, Precision: 0.8347
# Epoch 8/15 - Best Global Fitness: 0.8234
# Epoch 9/15
# Particle 1 evaluated. Fitness: 0.8279
# Particle 2 evaluated. Fitness: 0.8592
# Particle 3 evaluated. Fitness: 0.8360
# Particle 4 evaluated. Fitness: 0.8351
# Particle 5 evaluated. Fitness: 0.8504
# Particle 6 evaluated. Fitness: 0.8233
# Particle 7 evaluated. Fitness: 0.8432
# Particle 8 evaluated. Fitness: 0.8393
# Particle 9 evaluated. Fitness: 0.8229
# Particle 10 evaluated. Fitness: 0.8278
# New global best fitness: 0.8233
# New global best fitness: 0.8229
# Epoch 9/15 - Validation Loss: 0.4954, Precision: 0.8326
# Epoch 9/15 - Best Global Fitness: 0.8229
# Epoch 10/15
# Particle 1 evaluated. Fitness: 0.8294
# Particle 2 evaluated. Fitness: 0.8289
# Particle 3 evaluated. Fitness: 0.8347
# Particle 4 evaluated. Fitness: 0.8170
# Particle 5 evaluated. Fitness: 0.8730
# Particle 6 evaluated. Fitness: 0.8138
# Particle 7 evaluated. Fitness: 0.8588
# Particle 8 evaluated. Fitness: 0.8348
# Particle 9 evaluated. Fitness: 0.8480
# Particle 10 evaluated. Fitness: 0.8328
# New global best fitness: 0.8170
# New global best fitness: 0.8138
# Epoch 10/15 - Validation Loss: 0.4927, Precision: 0.8345
# Epoch 10/15 - Best Global Fitness: 0.8138
# Epoch 11/15
# Particle 1 evaluated. Fitness: 0.8307
# Particle 2 evaluated. Fitness: 0.8228
# Particle 3 evaluated. Fitness: 0.8310
# Particle 4 evaluated. Fitness: 0.8374
# Particle 5 evaluated. Fitness: 0.8414
# Particle 6 evaluated. Fitness: 0.8546
# Particle 7 evaluated. Fitness: 0.8483
# Particle 8 evaluated. Fitness: 0.8436
# Particle 9 evaluated. Fitness: 0.8467
# Particle 10 evaluated. Fitness: 0.8371
# Epoch 11/15 - Validation Loss: 0.4932, Precision: 0.8346
# Epoch 11/15 - Best Global Fitness: 0.8138
# Epoch 12/15
# Particle 1 evaluated. Fitness: 0.8670
# Particle 2 evaluated. Fitness: 0.8344
# Particle 3 evaluated. Fitness: 0.8554
# Particle 4 evaluated. Fitness: 0.8319
# Particle 5 evaluated. Fitness: 0.8629
# Particle 6 evaluated. Fitness: 0.8500
# Particle 7 evaluated. Fitness: 0.8631
# Particle 8 evaluated. Fitness: 0.8521
# Particle 9 evaluated. Fitness: 0.8332
# Particle 10 evaluated. Fitness: 0.8358
# Epoch 12/15 - Validation Loss: 0.4925, Precision: 0.8340
# Epoch 12/15 - Best Global Fitness: 0.8138
# Epoch 13/15
# Particle 1 evaluated. Fitness: 0.8391
# Particle 2 evaluated. Fitness: 0.8436
# Particle 3 evaluated. Fitness: 0.8420
# Particle 4 evaluated. Fitness: 0.8202
# Particle 5 evaluated. Fitness: 0.8546
# Particle 6 evaluated. Fitness: 0.8322
# Particle 7 evaluated. Fitness: 0.8313
# Particle 8 evaluated. Fitness: 0.8489
# Particle 9 evaluated. Fitness: 0.8320
# Particle 10 evaluated. Fitness: 0.8306
# Epoch 13/15 - Validation Loss: 0.4922, Precision: 0.8347
# Early stopping triggered
# Optimization completed. Best Global Fitness: 0.8138
# Returning from function
# Epoch Losses: [1.9432826892852784, 0.8867433289527893, 0.6530203974723816, 0.585192058467865, 0.5545766479492188, 0.5252063133239746, 0.5055126304626465, 0.48843651523590087, 0.49541441135406494, 0.492712641620636, 0.49315109167098997, 0.492522240447998, 0.49221888942718506]
# Epoch Precisions: [0.40795268626676584, 0.7021847317953298, 0.7755374121824637, 0.7997454078545736, 0.8111356542009253, 0.8270623110027291, 0.8306586086857003, 0.8347140408191357, 0.8326202547475535, 0.8345163850450458, 0.8345915116348241, 0.8340429920341929, 0.8347131310649633]

# %%
#Evaluation mode
trained_model.eval()

#Initialize evaluation metrics
correct = 0
total = 0
class_correct = {classname: 0 for classname in classes}
class_total = {classname: 0 for classname in classes}

#Accuracy on the whole test set
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = trained_model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        for label, prediction in zip(labels, predicted):
            if label == prediction:
                class_correct[classes[label.item()]] += 1
            class_total[classes[label.item()]] += 1

print('Accuracy of the network on the test images: %f %%' % (100 * correct / total))

#Accuracy for each class
for classname, correct_count in class_correct.items():
    accuracy = 100 * float(correct_count) / class_total[classname]
    print(f'Accuracy for class {classname:5s} is {accuracy:0.1f} %')

#Precision, Recall, F1 Score
all_labels = []
all_predictions = []

with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = trained_model(images)
        _, predicted = torch.max(outputs.data, 1)
        all_labels.extend(labels.cpu().numpy())
        all_predictions.extend(predicted.cpu().numpy())

precision = precision_score(all_labels, all_predictions, average='macro')
recall = recall_score(all_labels, all_predictions, average='macro')
f1 = f1_score(all_labels, all_predictions, average='macro')

print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Accuracy of the network on the test images: 83.420000 %
# Accuracy for class airplane is 83.2 %
# Accuracy for class automobile is 91.9 %
# Accuracy for class bird  is 72.8 %
# Accuracy for class cat   is 64.0 %
# Accuracy for class deer  is 85.9 %
# Accuracy for class dog   is 75.4 %
# Accuracy for class frog  is 92.4 %
# Accuracy for class horse is 84.5 %
# Accuracy for class ship  is 92.5 %
# Accuracy for class truck is 91.6 %
# Precision: 0.8347
# Recall: 0.8342
# F1 Score: 0.8326

# %%
plt.figure(figsize=(10, 6))
plt.plot(epoch_losses, label='Training Loss')
plt.plot(epoch_precisions, label='Average Precision')
plt.xlabel('Epochs')

plt.ylabel('Metrics')
plt.title('Training Loss and Average Precision Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Mapping to all labels and predictions
all_labels_names = CLPSO_GRAD_script.indices_to_class_names(all_labels, classes)
all_predictions_names = CLPSO_GRAD_script.indices_to_class_names(all_predictions, classes)

#Confusion Matrix
conf_matrix = confusion_matrix(all_labels, all_predictions)
plt.figure(figsize=(10,8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
